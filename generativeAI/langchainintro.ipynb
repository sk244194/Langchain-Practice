# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.4

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# This loads .env file

os.environ["GROQ_API_KEY"]= os.getenv("groq_api_key")
os.environ["GEMINI_API_KEY"] = os.getenv("gemini_api_key")

# %% [markdown]
# Using Groq

# %%
from langchain.chat_models import init_chat_model

# Search on google the name of model and model provider

llm = init_chat_model(
    model="llama-3.3-70b-versatile",
    model_provider="groq", 
    temperature=0
    # temperature tells how creative ai should be if closer to 1 then more creative but can create wrong answers
)

response= llm.invoke("Who created you")
# response
response.content
# Out:
# 'I was developed by researchers at Meta, whose mission is to give people the power to build community and bring the world closer together.'

# %%
from langchain.groq import ChatGroq
